# %%
# !pip install easyocr
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.9/871.9 kB 13.9 MB/s eta 0:00:00
# ...

# %%
import easyocr
reader = easyocr.Reader(['en'])
result = reader.readtext('image.webp',detail=0)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# !yolo detect predict source="image.webp" model=yolov10n.pt
# Out:
# ...
# 100% 5.59M/5.59M [00:00<00:00, 45.8MB/s]
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv10n summary (fused): 285 layers, 2,762,608 parameters, 0 gradients, 8.6 GFLOPs
#
# image 1/1 /content/image.webp: 640x640 (no detections), 334.4ms
# Speed: 12.2ms preprocess, 334.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('/content/runs/detect/predict/image.webp') #Replace "image.jpg" with the path of your image
plt.imshow(img)
plt.axis('off')
plt.show()
result
# Out:
# ['89', '004']
